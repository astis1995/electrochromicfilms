# %% [markdown]
# Análisis de datos
# Laboratorio Avanzado II
# Estudiante: Esteban Vinicio Soto Monge

# %% [markdown]
# Fecha 20230619

# %%
#dependencies
import pandas as pd
import numpy as np
import matplotlib
import os

# %%
#electrodeposition_WO3_thin_films_onto_ITO
filename = r"E:\Laboratorio Avanzado\20230619\electrodeposition_WO3_thin_films_onto_ITO\wo3_film_continuous_electrodeposition_A\CA_2"
df = pd.read_csv(filename, header = 0, delimiter="\t", names=["time", "current", "potential"])
nick = { "time" :"Time (s)",	"current" :"WE(1).Current (A)", "voltage" : 	"WE(1).Potential (V)"}
df
# Out:
#             time   current  potential
# 0      72.061754 -0.001703  -0.699646
# 1      72.161754 -0.001653  -0.698975
# 2      72.261754 -0.001664  -0.699219
# 3      72.361754 -0.001692  -0.699036
# 4      72.461754 -0.001723  -0.698914
# ...          ...       ...        ...
# 3495  421.561753 -0.004766  -0.699402
# 3496  421.661753 -0.004766  -0.699188
# 3497  421.761753 -0.004766  -0.699493
# 3498  421.861753 -0.004766  -0.699310
# 3499  421.961753 -0.004766  -0.699402
#
# [3500 rows x 3 columns]

# %%
ax = df.plot(x = "time", y= "current", grid = True)
ax.set_xlabel(nick["time"])
ax.set_ylabel(nick["current"])
fig = ax.figure

# %%
#Diffuse transmittance 20230918
